# %% [markdown]
# # LOADING DATA

# %%
import pandas as pd
Data = (r"C:\Users\Admin\Downloads\01.Data Cleaning and Preprocessing.csv")
df = pd.read_csv(Data)

# %%
# Display the first few rows of the DataFrame
print("Initial DataFrame:")
print(df.head())
# Out:
# Initial DataFrame:
#   Observation  Y-Kappa  ChipRate  BF-CMratio  BlowFlow  ChipLevel4   \
# 0    31-00:00    23.10    16.520     121.717  1177.607      169.805
# 1    31-01:00    27.60    16.810      79.022  1328.360      341.327
# 2    31-02:00    23.19    16.709      79.562  1329.407      239.161
# 3    31-03:00    23.60    16.478      81.011  1334.877      213.527
# 4    31-04:00    22.90    15.618      93.244  1334.168      243.131
#
#    T-upperExt-2   T-lowerExt-2    UCZAA  WhiteFlow-4   ...  SteamFlow-4   \
# 0        358.282         329.545  1.443       599.253  ...        67.122
# 1        351.050         329.067  1.549       537.201  ...        60.012
# 2        350.022         329.260  1.600       549.611  ...        61.304
# 3        350.938         331.142  1.604       623.362  ...        68.496
# 4        351.640         332.709    NaN       638.672  ...        70.022
#
#    Lower-HeatT-3  Upper-HeatT-3   ChipMass-4   WeakLiquorF   BlackFlow-2   \
# ...

# %% [markdown]
# # DATA FILTERING

# %%
# Example: Filter rows where 'ChipRate' is greater than a threshold, say 100
filtered_df = df[df['ChipRate'] > 100]

print("\nFiltered DataFrame (ChipRate > 100):")
print(filtered_df.head())
# Out:
# Filtered DataFrame (ChipRate > 100):
# Empty DataFrame
# Columns: [Observation, Y-Kappa, ChipRate, BF-CMratio, BlowFlow, ChipLevel4 , T-upperExt-2 , T-lowerExt-2  , UCZAA, WhiteFlow-4 , AAWhiteSt-4 , AA-Wood-4  , ChipMoisture-4 , SteamFlow-4 , Lower-HeatT-3, Upper-HeatT-3 , ChipMass-4 , WeakLiquorF , BlackFlow-2 , WeakWashF , SteamHeatF-3 , T-Top-Chips-4 , SulphidityL-4 ]
# Index: []
#
# [0 rows x 23 columns]

# %%
# Filter rows where 'ChipRate' is greater than 100 and 'BlowFlow' is less than 200
filtered_df_multi = df[(df['ChipRate'] > 100) & (df['BlowFlow'] < 200)]
print("\nFiltered DataFrame (ChipRate > 100 and BlowFlow < 200):")
print(filtered_df_multi.head())
# Out:
# Filtered DataFrame (ChipRate > 100 and BlowFlow < 200):
# Empty DataFrame
# Columns: [Observation, Y-Kappa, ChipRate, BF-CMratio, BlowFlow, ChipLevel4 , T-upperExt-2 , T-lowerExt-2  , UCZAA, WhiteFlow-4 , AAWhiteSt-4 , AA-Wood-4  , ChipMoisture-4 , SteamFlow-4 , Lower-HeatT-3, Upper-HeatT-3 , ChipMass-4 , WeakLiquorF , BlackFlow-2 , WeakWashF , SteamHeatF-3 , T-Top-Chips-4 , SulphidityL-4 ]
# Index: []
#
# [0 rows x 23 columns]

# %%
# Example: Filter rows where 'ChipRate' is in a specific list of values
chiprate_list = [95, 105, 110]
filtered_df_in_list = df[df['ChipRate'].isin(chiprate_list)]
print("\nFiltered DataFrame (ChipRate in [95, 105, 110]):")
print(filtered_df_in_list.head())

# Filter rows where 'BlowFlow' is not in a specific list of values
blowflow_list = [200, 210]
filtered_df_not_in_list = df[~df['BlowFlow'].isin(blowflow_list)]
print("\nFiltered DataFrame (BlowFlow not in [200, 210]):")
print(filtered_df_not_in_list.head())
# Out:
# Filtered DataFrame (ChipRate in [95, 105, 110]):
# Empty DataFrame
# Columns: [Observation, Y-Kappa, ChipRate, BF-CMratio, BlowFlow, ChipLevel4 , T-upperExt-2 , T-lowerExt-2  , UCZAA, WhiteFlow-4 , AAWhiteSt-4 , AA-Wood-4  , ChipMoisture-4 , SteamFlow-4 , Lower-HeatT-3, Upper-HeatT-3 , ChipMass-4 , WeakLiquorF , BlackFlow-2 , WeakWashF , SteamHeatF-3 , T-Top-Chips-4 , SulphidityL-4 ]
# Index: []
#
# [0 rows x 23 columns]
#
# Filtered DataFrame (BlowFlow not in [200, 210]):
#   Observation  Y-Kappa  ChipRate  BF-CMratio  BlowFlow  ChipLevel4   \
# 0    31-00:00    23.10    16.520     121.717  1177.607      169.805
# 1    31-01:00    27.60    16.810      79.022  1328.360      341.327
# 2    31-02:00    23.19    16.709      79.562  1329.407      239.161
# 3    31-03:00    23.60    16.478      81.011  1334.877      213.527
# 4    31-04:00    22.90    15.618      93.244  1334.168      243.131
#
#    T-upperExt-2   T-lowerExt-2    UCZAA  WhiteFlow-4   ...  SteamFlow-4   \
# ...

# %%
# Example: Filter rows by their index values
index_list = [0, 2, 4]
filtered_df_index = df.loc[index_list]
print("\nFiltered DataFrame (Index in [0, 2, 4]):")
print(filtered_df_index)
# Out:
# Filtered DataFrame (Index in [0, 2, 4]):
#   Observation  Y-Kappa  ChipRate  BF-CMratio  BlowFlow  ChipLevel4   \
# 0    31-00:00    23.10    16.520     121.717  1177.607      169.805
# 2    31-02:00    23.19    16.709      79.562  1329.407      239.161
# 4    31-04:00    22.90    15.618      93.244  1334.168      243.131
#
#    T-upperExt-2   T-lowerExt-2    UCZAA  WhiteFlow-4   ...  SteamFlow-4   \
# 0        358.282         329.545  1.443       599.253  ...        67.122
# 2        350.022         329.260  1.600       549.611  ...        61.304
# 4        351.640         332.709    NaN       638.672  ...        70.022
#
#    Lower-HeatT-3  Upper-HeatT-3   ChipMass-4   WeakLiquorF   BlackFlow-2   \
# 0        329.432         303.099      175.964      1127.197      1319.039
# 2        329.140         303.383      164.013       677.534      1327.072
# 4        328.352         300.954      183.929       888.448      1343.424
#
# ...

# %% [markdown]
# # HANDLE MISSING VALUES

# %%
# Example: Fill missing values with the mean of the column
df_filled = df.fillna(df.mean(numeric_only=True))

print("\nDataFrame with missing values filled:")
print(df_filled.head())

# Alternatively, drop rows with missing values
df_dropped = df.dropna()

print("\nDataFrame with missing values dropped:")
print(df_dropped.head())
# Out:
# DataFrame with missing values filled:
#   Observation  Y-Kappa  ChipRate  BF-CMratio  BlowFlow  ChipLevel4   \
# 0    31-00:00    23.10    16.520     121.717  1177.607      169.805
# 1    31-01:00    27.60    16.810      79.022  1328.360      341.327
# 2    31-02:00    23.19    16.709      79.562  1329.407      239.161
# 3    31-03:00    23.60    16.478      81.011  1334.877      213.527
# 4    31-04:00    22.90    15.618      93.244  1334.168      243.131
#
#    T-upperExt-2   T-lowerExt-2      UCZAA  WhiteFlow-4   ...  SteamFlow-4   \
# 0        358.282         329.545  1.44300       599.253  ...        67.122
# 1        351.050         329.067  1.54900       537.201  ...        60.012
# 2        350.022         329.260  1.60000       549.611  ...        61.304
# 3        350.938         331.142  1.60400       623.362  ...        68.496
# 4        351.640         332.709  1.49201       638.672  ...        70.022
#
# ...

# %% [markdown]
# # SUMMARY STATISTICS

# %%
summary_stats = df.describe()

print("\nSummary statistics:")
print(summary_stats)
# Out:
# Summary statistics:
#           Y-Kappa    ChipRate  BF-CMratio     BlowFlow  ChipLevel4   \
# count  324.000000  319.000000  307.000000   308.000000   323.000000
# mean    20.635370   14.347937   87.464456  1237.837614   258.164483
# std      3.070036    1.499095    7.995012   100.593735    87.987452
# min     12.170000    9.983000   68.645000     0.000000     0.000000
# 25%     18.382500   13.358000   81.823000  1193.215250   213.527000
# 50%     20.845000   14.308000   86.739000  1273.138500   271.792000
# 75%     23.032500   15.517000   92.372000  1289.196000   321.680000
# max     27.600000   16.958000  121.717000  1351.240000   419.014000
#
#        T-upperExt-2   T-lowerExt-2         UCZAA  WhiteFlow-4   AAWhiteSt-4   \
# count     322.000000      322.000000  299.000000    323.000000    173.000000
# mean      356.904295      324.020180    1.492010    591.732260      6.140410
# std         9.209290        7.621402    0.105923     67.016351      0.081609
# ...

# %%
# Mean of numerical columns
mean_values = df.mean(numeric_only=True)
print("\nMean Values:")
print(mean_values)
# Out:
# Mean Values:
# Y-Kappa              20.635370
# ChipRate             14.347937
# BF-CMratio           87.464456
# BlowFlow           1237.837614
# ChipLevel4          258.164483
# T-upperExt-2        356.904295
# T-lowerExt-2        324.020180
# UCZAA                 1.492010
# WhiteFlow-4         591.732260
# AAWhiteSt-4           6.140410
# AA-Wood-4            17.835885
# ChipMoisture-4       46.781969
# SteamFlow-4          66.668285
# Lower-HeatT-3       325.567820
# Upper-HeatT-3       300.525699
# ChipMass-4          162.222322
# WeakLiquorF         873.828941
# BlackFlow-2        1175.917016
# WeakWashF           263.543068
# SteamHeatF-3         49.696907
# T-Top-Chips-4       251.240087
# SulphidityL-4        30.411671
# dtype: float64

# %%
# Median of numerical columns
median_values = df.median(numeric_only=True)
print("\nMedian Values:")
print(median_values)
# Out:
# Median Values:
# Y-Kappa              20.8450
# ChipRate             14.3080
# BF-CMratio           86.7390
# BlowFlow           1273.1385
# ChipLevel4          271.7920
# T-upperExt-2        356.8430
# T-lowerExt-2        325.6690
# UCZAA                 1.4980
# WhiteFlow-4         592.8950
# AAWhiteSt-4           6.1350
# AA-Wood-4            17.7590
# ChipMoisture-4       46.8460
# SteamFlow-4          67.4290
# Lower-HeatT-3       324.7410
# Upper-HeatT-3       299.1260
# ChipMass-4          163.6900
# WeakLiquorF         865.2540
# BlackFlow-2        1150.2215
# WeakWashF           269.1930
# SteamHeatF-3         50.2770
# T-Top-Chips-4       251.3800
# SulphidityL-4        30.3700
# dtype: float64

# %%
# Standard deviation of numerical columns
std_values = df.std(numeric_only=True)
print("\nStandard Deviation Values:")
print(std_values)
# Out:
# Standard Deviation Values:
# Y-Kappa              3.070036
# ChipRate             1.499095
# BF-CMratio           7.995012
# BlowFlow           100.593735
# ChipLevel4          87.987452
# T-upperExt-2         9.209290
# T-lowerExt-2         7.621402
# UCZAA                0.105923
# WhiteFlow-4         67.016351
# AAWhiteSt-4          0.081609
# AA-Wood-4            0.913390
# ChipMoisture-4       1.480862
# SteamFlow-4          5.708587
# Lower-HeatT-3        4.609862
# Upper-HeatT-3        4.568484
# ChipMass-4          14.160688
# WeakLiquorF        122.073521
# BlackFlow-2        149.334010
# WeakWashF          163.666942
# SteamHeatF-3         4.551909
# T-Top-Chips-4        1.283432
# SulphidityL-4        0.701317
# dtype: float64

# %%
# Minimum values of numerical columns
min_values = df.min(numeric_only=True)
print("\nMinimum Values:")
print(min_values)

# Maximum values of numerical columns
max_values = df.max(numeric_only=True)
print("\nMaximum Values:")
print(max_values)
# Out:
# Minimum Values:
# Y-Kappa             12.170
# ChipRate             9.983
# BF-CMratio          68.645
# BlowFlow             0.000
# ChipLevel4           0.000
# T-upperExt-2       339.168
# T-lowerExt-2       284.633
# UCZAA                1.182
# WhiteFlow-4        405.111
# AAWhiteSt-4          5.890
# AA-Wood-4           16.471
# ChipMoisture-4      42.822
# SteamFlow-4         48.568
# Lower-HeatT-3      318.051
# Upper-HeatT-3      293.312
# ChipMass-4         113.922
# WeakLiquorF        486.938
# BlackFlow-2        838.948
# WeakWashF            0.000
# SteamHeatF-3        35.510
# T-Top-Chips-4      248.359
# SulphidityL-4       29.010
# dtype: float64
#
# Maximum Values:
# Y-Kappa              27.600
# ChipRate             16.958
# BF-CMratio          121.717
# BlowFlow           1351.240
# ChipLevel4          419.014
# T-upperExt-2        399.135
# T-lowerExt-2        337.012
# UCZAA                 1.747
# WhiteFlow-4         731.394
# AAWhiteSt-4           6.340
# ...

# %%
# Correlation matrix
correlation_matrix = df.corr(numeric_only=True)
print("\nCorrelation Matrix:")
print(correlation_matrix)
# Out:
# Correlation Matrix:
#                   Y-Kappa  ChipRate  BF-CMratio  BlowFlow  ChipLevel4   \
# Y-Kappa          1.000000  0.096039   -0.274750 -0.054174     0.449745
# ChipRate         0.096039  1.000000   -0.588323  0.400427    -0.064581
# BF-CMratio      -0.274750 -0.588323    1.000000 -0.120019    -0.014095
# BlowFlow        -0.054174  0.400427   -0.120019  1.000000     0.069848
# ChipLevel4       0.449745 -0.064581   -0.014095  0.069848     1.000000
# T-upperExt-2    -0.195364  0.089823    0.050485  0.148905    -0.256777
# T-lowerExt-2    -0.284447  0.499084   -0.122767  0.377123    -0.348202
# UCZAA           -0.148441  0.130185   -0.100513 -0.032827    -0.332661
# WhiteFlow-4     -0.512233  0.450368   -0.067566  0.297017    -0.318796
# AAWhiteSt-4      0.156829  0.011664   -0.045641  0.069947     0.399021
# AA-Wood-4       -0.334914  0.223485   -0.152923  0.079066    -0.112015
# ChipMoisture-4  -0.406685  0.123577    0.018842  0.018152    -0.042924
# ...

# %%
# Count of non-null entries in each column
count_values = df.count(numeric_only=True)
print("\nCount Values:")
print(count_values)
# Out:
# Count Values:
# Y-Kappa            324
# ChipRate           319
# BF-CMratio         307
# BlowFlow           308
# ChipLevel4         323
# T-upperExt-2       322
# T-lowerExt-2       322
# UCZAA              299
# WhiteFlow-4        323
# AAWhiteSt-4        173
# AA-Wood-4          323
# ChipMoisture-4     323
# SteamFlow-4        323
# Lower-HeatT-3      322
# Upper-HeatT-3      322
# ChipMass-4         323
# WeakLiquorF        323
# BlackFlow-2        322
# WeakWashF          323
# SteamHeatF-3       322
# T-Top-Chips-4      323
# SulphidityL-4      173
# dtype: int64
